# %% [markdown]
# **Bokeh 심화 -  지리 데이터 시각화**
#
# 이번엔 보케를 이용해 지리데이터를 시각화 해보도록 하겠습니다.
#
# 사용할 데이터는 미국의 킹 주(county)의 집들에 대한 정보가 담긴 데이터셋입니다.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
house_df = pd.read_csv("kc_house_data.csv")
house_df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# 뒤에 진행될 시각화를 위해서 가격 기준으로 집들을 범주화 해줍니다.

# %%
house_df.plot(kind='box', y='price')
plt.show()

# %%
house_df.price.describe()
# Out:
# count    2.161300e+04
# mean     5.401822e+05
# std      3.673622e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
def categorize(price):
    if price <= 300000:
        return "1"
    elif price > 450000 and price <= 700000:
        return "2"
    elif price > 2000000 and price <= 3500000:
        return "3"
    elif price > 4000000:
        return "4"
    else:
        return None
    
house_df["price_category"] = house_df["price"].apply(categorize)

# %%
house_df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %% [markdown]
# 이렇게 정의된 데이터에서 `price_category` 칼럼을 기준으로 집들의 분포를 지도에 플로팅 시켜보도록 하겠습니다.
#
# 보케에서 지리데이터를 시각화 하는 방법은 크게 세가지가 있습니다
#
# 1. **구글맵 이용하기**: 가장 간단하지만, 구글맵 API가 필요합니다.
# 2. **보케에서 제공하는 Tile Provider 이용하기**: 마찬가지로 간단하지만, 좌표계를 web mercator 좌표계로 변환해야 합니다.
# 3. **패치 플롯 이용하기**: 이것 저것 할 수 있는게 많지만, border line 좌표들을 직접 가져와서 맵을 정의해줘야 합니다.
#
# 이 중에서 1,2 번 방법은 여기서 알아보고, 3번은 내용이 좀 복잡해서 다음 파트에서 자세히 다루겠습니다.

# %% [markdown]
# # 방법1: 구글맵 이용하기
#
# - API가 필요합니다.
# - API를 발급받는 방법은 https://webruden.tistory.com/378 을 참고해주세요.

# %%
from bokeh.io import output_notebook, show
from bokeh.models import ColumnDataSource, GMapOptions
from bokeh.layouts import layout
from bokeh.plotting import gmap
from bokeh.models.widgets import RadioGroup

# %%
def bkapp(doc):
    APIkey = ""  ## 구글맵 API를 발급받으세요.
    map_options = GMapOptions(lat=47.5480, lng=-121.9836, map_type="roadmap", zoom=10)

    plot = gmap(APIkey, map_options, title="King County", width=1000, height=600)

    source = ColumnDataSource(data = {
        "lat": house_df[house_df.price_category == "1"].lat,
        "long": house_df[house_df.price_category == "1"].long
    })

    plot.circle(x="long", y="lat", size=3, fill_color="blue", fill_alpha=0.5, source=source)



    # Define the callback function
    def radio_update(attr, old, new):
        active = radio.active
        categories = ["1", "2", "3", "4"]
        
        source.data = {
            "lat": house_df[house_df.price_category == categories[active]].lat,
            "long": house_df[house_df.price_category == categories[active]].long
        }


    # Create radio button
    radio = RadioGroup(labels=["낮음", "중간", "비쌈", "개비쌈"], active=0)
    radio.on_change("active", radio_update)


    # Application on Jupyter notebook
    doc.add_root(layout([plot, radio], sizing_mode='stretch_width'))

# %%
output_notebook()
show(bkapp)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
# <script id="1002">
#   var xhr = new XMLHttpRequest()
#   xhr.responseType = 'blob';
#   xhr.open('GET', "http://localhost:58495/autoload.js?bokeh-autoload-element=1002&bokeh-absolute-url=http://localhost:58495&resources=none", true);
#
#   xhr.onload = function (event) {
#     var script = document.createElement('script'),
#     src = URL.createObjectURL(event.target.response);
#     script.src = src;
#     document.body.appendChild(script);
#   };
# xhr.send();
# </script>

# %% [markdown]
# # 방법 2: Bokeh Tile provider 이용하기
#
# 좌표 변환 공식은 [다음의 사이트](https://stackoverflow.com/questions/59685419/change-projection-of-tile-provider-in-bokeh-in-epsg3857-web-mercator-to-my) 를 참고했습니다.

# %%
house_df.head(3)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
#
#    sqft_lot15  price_category
# 0        5650               1
# 1        7639               2
# ...

# %%
# 좌표변환

import numpy as np

def lon_to_web_mercator(lon):
    k = 6378137
    return lon * (k * np.pi / 180.0)

def lat_to_web_mercator(lat):
    k = 6378137
    return np.log(np.tan((90 + lat) * np.pi / 360.0)) * k

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.tile_providers import get_provider, OSM


# range bounds supplied in web mercator coordinates
plot = figure(x_range=(-2000000, 6000000), y_range=(-1000000, 7000000), 
              x_axis_type="mercator", y_axis_type="mercator", 
              width=800, height=600)

tile_provider = get_provider(OSM)
plot.add_tile(tile_provider)


source = ColumnDataSource(data = {
    "lat": house_df[house_df.price_category == "1"].lat.apply(lat_to_web_mercator),
    "long": house_df[house_df.price_category == "1"].long.apply(lon_to_web_mercator)
})

plot.circle(x="long", y="lat", size=3, fill_color="blue", fill_alpha=0.5, source=source)

show(plot)
# Out:
#   <div class="bk-root" id="d7920946-e051-43ac-9034-4c99f55c3153" data-root-id="1003"></div>
